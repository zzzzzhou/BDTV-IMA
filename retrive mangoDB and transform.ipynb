# %%
from pymongo import MongoClient
import pandas as pd
# final version
con_str = "mongodb+srv://zzd:zhouzhedi0928@cluster0.lae6q.mongodb.net/sample_analytics?retryWrites=true&w=majority"
client = MongoClient(con_str)
db2 = client.US_covid # database
collection2 = db2.population # select the customers collection
record2 = collection2.find()
i=0
populationoutput={}
for each in record2:
    populationoutput[i] = {"state":each[str(i)]['State'], "population":each[str(i)]['Population']}
    i = i+1  #retrive the population data from mango DB，only keep state name and population data

output={}
db = client.US_covid # database
collection = db.covid_cases_state_level # select the state data collection
record = collection.find()
id = 0
for doc in record:
    for hisdata in doc['key']['historicData']:
        output[id] = {"statename" : hisdata['provinceStateName'],"totalPOS" : hisdata['peoplePositiveCasesCt'],"totaldeath" : hisdata['deathCt'],"date" : hisdata['date'], "dailynewpos":'null',"dailynewdeath":'null' 
        }
        id = id+1  #retrive the covid data from mango DB, keep total positive, total death, state name, date. and creat two new column daily newpos and daily death
        
for i in range(len(output)):
    for j in range(len(populationoutput)):
        if output[i]['statename'] == populationoutput[j]['state']:
            output[i]['population'] = populationoutput[j]['population']
            if (i%6) != 0 :
                output[i]['dailynewpos'] = output[i]['totalPOS'] - output[i-1]['totalPOS']
                output[i]['dailynewdeath'] = output[i]['totaldeath'] - output[i-1]['totaldeath']
            else:
                continue
        else:
            continue
output #join state population data with covid data, and calculate daily new pos, daily new death

#newdb=client.transformed_data
#newtable=newdb.linkedtable
#for key in output.keys():
    #newtable.insert_one({str(key): output[key]}) #store data into mangoDB in a new table ##in case not to overwrite data into mango DB


output_df = pd.DataFrame(output)
output_df = output_df.transpose()
output_df.to_csv('transformed data.csv', sep=",") # output CSV
# Out:
# {0: {'statename': 'Alabama',
#   'totalPOS': 921175,
#   'totaldeath': 16496,
#   'date': '2022-01-04',
#   'dailynewpos': 'null',
#   'dailynewdeath': 'null',
#   'population': 4903185},
#  1: {'statename': 'Alabama',
#   'totalPOS': 932250,
#   'totaldeath': 16503,
#   'date': '2022-01-05',
#   'dailynewpos': 11075,
#   'dailynewdeath': 7,
#   'population': 4903185},
#  2: {'statename': 'Alabama',
#   'totalPOS': 944876,
#   'totaldeath': 16543,
#   'date': '2022-01-06',
#   'dailynewpos': 12626,
#   'dailynewdeath': 40,
#   'population': 4903185},
#  3: {'statename': 'Alabama',
#   'totalPOS': 957848,
#   'totaldeath': 16585,
#   'date': '2022-01-07',
#   'dailynewpos': 12972,
#   'dailynewdeath': 42,
#   'population': 4903185},
#  4: {'statename': 'Alabama',
#   'totalPOS': 966180,
#   'totaldeath': 16624,
#   'date': '2022-01-08',
#   'dailynewpos': 8332,
#   'dailynewdeath': 39,
#   'population': 4903185},
#  5: {'statename': 'Alabama',
#   'totalPOS': 978632,
# ...
